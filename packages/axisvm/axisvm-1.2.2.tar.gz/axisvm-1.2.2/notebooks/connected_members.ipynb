# %%
from axisvm.com.client import start_AxisVM
from axisvm import examples

axvm = start_AxisVM(visible=True, daemon=False, join=True)
axvm.model = examples.download_bernoulli_grid()

# %%
axvm.model.Members.get_connected_member_ids(201)
# Out:
# {201: (array([458, 521, 522], dtype=int64), array([1, 0, 0], dtype=int64))}

# %%
axvm.model.Windows[1].screenshot()
# Out:
# <PIL.BmpImagePlugin.DibImageFile image mode=RGB size=964x898>
